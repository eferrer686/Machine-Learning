# %%
import numpy as np

# %%
X = np.array(([[3,5], [5,1],[10,2]]),dtype=float)
y = np.array(([[75], [82],[93]]),dtype=float)

# %%
print(X)
# Out:
# [[ 3.  5.]
#  [ 5.  1.]
#  [10.  2.]]

# %%
Xn = X/X.max()

# %%
print(Xn)
# Out:
# [[0.3 0.5]
#  [0.5 0.1]
#  [1.  0.2]]

# %%
yn = y/100
print(yn)
# Out:
# [[0.75]
#  [0.82]
#  [0.93]]

# %%
class RedNeuronal():
    def __init__(self):
        self.inputs = 2
        self.outputs = 1
        self.hidden = 3
        self.W1 = np.random.rand(self.inputs, self.hidden)
        self.W2 = np.random.rand(self.hidden, self.outputs)
    def sigmoide(self, Z):
        return 1 / (1 + np.exp(-Z))

# %%
rn = RedNeuronal()

# %%
np.random.rand(2, 3)
np.random.rand(3, 1)
# Out:
# array([[0.51383149],
#        [0.48946647],
#        [0.6096324 ]])

# %%
W1 = np.array([[.3,-.7,.1], [.2,.9,-.3]])

# %%
Z2 = X @ W1
print(Z2)
# Out:
# [[ 1.9  2.4 -1.2]
#  [ 1.7 -2.6  0.2]
#  [ 3.4 -5.2  0.4]]

# %%
W2 = np.array([[.24],[.45], [.1]])

# %%
def sigmoide(Z):
        return 1 / (1 + np.exp(-Z))

# %%
a2 = sigmoide(Z2)

# %%
print(a2)
# Out:
# [[0.86989153 0.9168273  0.23147522]
#  [0.84553473 0.06913842 0.549834  ]
#  [0.96770454 0.0054863  0.59868766]]

# %%
Z3 =  a2 @ W2
print(Z3)
# Out:
# [[0.64449377]
#  [0.28902403]
#  [0.29458669]]

# %%
yhat = sigmoide(Z3)

# %%
print(yhat)
# Out:
# [[0.65576858]
#  [0.57175718]
#  [0.57311866]]

# %%
class RedNeuronal():
    def __init__(self):
        self.inputs = 2
        self.outputs = 1
        self.hidden = 3
        self.W1 = np.random.rand(self.inputs, self.hidden)
        self.W2 = np.random.rand(self.hidden, self.outputs)
    def sigmoide(self, Z):
        return 1 / (1 + np.exp(-Z))
    def feedForward(self, X):
        self.Z2 =  X @ self.W1  #XW1
        self.a2 =  self.sigmoide(self.Z2)   #f(Z2)
        self.Z3 =   self.a2 @ self.W2 #a2W2
        self.yhat =  self.sigmoide(self.Z3)#f(Z3)
        return self.yhat

# %%
rn = RedNeuronal()

# %%
yhat = rn.feedForward(Xn)

# %%
yhat
# Out:
# array([[0.69291824],
#        [0.69510193],
#        [0.71661826]])

# %%
yn
# Out:
# array([[0.75],
#        [0.82],
#        [0.93]])

# %%
print(yn - yhat)
# Out:
# [[0.05708176]
#  [0.12489807]
#  [0.21338174]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bikes = pd.read_csv("hour.csv")

# %%
bikes
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# 5            6  2011-01-01       1   0     1   5        0        6
# 6            7  2011-01-01       1   0     1   6        0        6
# 7            8  2011-01-01       1   0     1   7        0        6
# 8            9  2011-01-01       1   0     1   8        0        6
# 9           10  2011-01-01       1   0     1   9        0        6
# 10          11  2011-01-01       1   0     1  10        0        6
# 11          12  2011-01-01       1   0     1  11        0        6
# 12          13  2011-01-01       1   0     1  12        0        6
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %%
bikes[:].plot(x="dteday", y="cnt")

# %%
yn.ravel()
# Out:
# array([0.75, 0.82, 0.93])

# %%
plt.bar([0,1,2], yn.ravel(), width=0.40, alpha=0.8)
plt.bar([0.35, 1.35, 2.35], yhat.ravel(), width=0.40, 
        color='r', alpha=0.9)
plt.grid(1)
plt.legend(['y', 'yhat'])
plt.show()

# %%
def sigmoideDerivada(z):
        return np.exp(-z)/((1+np.exp(-z))**2)

# %%
pruebaSigmoides = np.arange(-5, 5, 0.01)
#print(pruebaSigmoides)
plt.plot(pruebaSigmoides, sigmoide(pruebaSigmoides), linewidth= 2)
plt.plot(pruebaSigmoides, \
     sigmoideDerivada(pruebaSigmoides), linewidth= 2)
plt.grid(1)
plt.legend(["sigmoide", "derivadaSigmoide"])

# %%
class RedNeuronal():
    def __init__(self):
        self.inputs = 2
        self.outputs = 1
        self.hidden = 3
        self.W1 = np.random.rand(self.inputs, self.hidden)
        self.W2 = np.random.rand(self.hidden, self.outputs)
    def sigmoide(self, Z):
        return 1 / (1 + np.exp(-Z))
    def feedForward(self, X):
        self.Z2 =  X @ self.W1  #XW1
        self.a2 =  self.sigmoide(self.Z2)   #f(Z2)
        self.Z3 =   self.a2 @ self.W2 #a2W2
        self.yhat =  self.sigmoide(self.Z3)#f(Z3)
        return self.yhat
    def sigmoideDerivada(self, Z):
        return np.exp(-Z)/((1+np.exp(-Z))**2)
    
    def funcionCosto(self, X, y):
        self.yhat = self.feedForward(X)
        Costo = 0.5*sum((y-self.yhat)**2)
        return Costo
    
    def funcionDeCostoDerivada(self, X, y):
        #Predicciones
        self.yhat = self.feedForward(X)
        #delta3 = diferencia de y -yhat * derivadaFuncionActivacion
        self.delta3 = np.multiply( -(y-self.yhat),\
                                  self.sigmoideDerivada(self.Z3))
        
        #djW2 = producto transpuesta a2 * delta 3
        djW2 = self.a2.T @ self.delta3
        
        #delta2 = delta3 * transpuesta W2 * sigmoideDerivada Z2
        self.delta2 = self.delta3@self.W2.T *self.sigmoideDerivada(self.Z2)
        #djDW1 delta2 * trasnpuesta X
        djW1 = X.T @ self.delta2 
        return djW1, djW2

    def getPesos(self):
        data = np.concatenate((self.W1.ravel(), self.W2.ravel()))
        return data
   
    def setPesos(self, datos):
        W1_inicio = 0
        W1_fin = self.hidden * self.inputs
        self.W1 = np.reshape(datos[W1_inicio:W1_fin], (self.inputs , self.hidden))
        W2_fin = W1_fin + self.hidden*self.outputs
        self.W2 = np.reshape(datos[W1_fin:W2_fin], (self.hidden, self.outputs))
   
    def getGradientes(self, X, y):
        djW1, djW2 = self.funcionDeCostoDerivada(X, y)
        return np.concatenate((djW1.ravel(), djW2.ravel()))

# %% [markdown]
# # https://pastebin.com/SmGk7JLM

# %%
rn = RedNeuronal()
error = rn.funcionCosto(Xn, yn)
print(error)
# Out:
# [0.03987885]

# %%
djW1, djW2 = rn.funcionDeCostoDerivada(Xn,yn)

# %%
print(djW1)
# Out:
# [[-0.00084358 -0.01233045 -0.00524841]
#  [-0.00024752 -0.0036406  -0.00151986]]

# %%
print(djW2)
# Out:
# [[-0.05716085]
#  [-0.06415152]
#  [-0.05800016]]

# %%
escalar = 3
rn.W1 = rn.W1 + escalar *djW1
rn.W2 = rn.W2 + escalar *djW2
errorDos = rn.funcionCosto(Xn,yn)

# %%
print(error, errorDos)
# Out:
# [0.03987885] [0.08328773]

# %%
djW1, djW2 = rn.funcionDeCostoDerivada(Xn, yn)

# %%
rn.W1 = rn.W1 - escalar*djW1
rn.W2 = rn.W2 - escalar*djW2
errorTres = rn.funcionCosto(Xn,yn)

# %%
print(error, errorDos, errorTres)
# Out:
# [0.03987885] [0.08328773] [0.02241424]

# %%
from scipy import optimize
class Entrenador:
    def __init__(self, unaRed):
        #referencia a una red local
        self.NN = unaRed
       
    def actualizaPesos(self, params):
        self.NN.setPesos(params)
        self.Costos.append(self.NN.funcionCosto(self.X, self.y))  
        self.CostosTest.append(self.NN.costFunction(self.Xtest, self.ytest))
       
    def obtenPesosNN(self, params, X, y):
        self.NN.setPesos(params)
        cost = self.NN.funcionCosto(X, y)
        grad = self.NN.getGradientes(X,y)        
        return cost, grad
       
    def entrena(self, X, y, Xtest, ytest):
        # variables para funciones callback
        self.X = X
        self.y = y
        
        self.Xtest = Xtest
        self.ytest = ytest
       
    
        # lista temporal de costos
        self.Costos = []
        self.CostosTest = []
        
        pesos = self.NN.getPesos()
 
        opciones = {'maxiter': 200, 'disp' : True}
       
        #self.obtenPesosNN, funcion objetivo
        #args=(X, y), input / output data
        # salida, regresa el costo y los gradientes
        salida = optimize.minimize(self.obtenPesosNN, pesos, jac=True, method='BFGS', \
                                 args=(X, y), options=opciones, callback=self.actualizaPesos)
 
        self.NN.setPesos(salida.x)
        self.resultados = salida

# %%
nn = RedNeuronal()

# %%
e = Entrenador(nn)

# %%
#Entrenamiento
trainX = np.array(([3,5], [5,1], [10,2], [6,1.5]), dtype=float)
trainY = np.array(([75], [82], [93], [70]), dtype=float)
 
#Pruebas
testX = np.array(([4, 5.5], [4.5,1], [9,2.5], [6, 2]), dtype=float)
testY = np.array(([70], [89], [85], [75]), dtype=float)
 
#Normalización
trainX = trainX/np.amax(trainX, axis=0)
trainY = trainY/100
 
testX = testX/np.amax(trainX, axis=0)
testY = testY/100

# %%
e.entrena(trainX, trainY, testX, testY)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-d46f9b001baf> in <module>()
# ----> 1 e.entrena(trainX, trainY, testX, testY)
#
# <ipython-input-63-421145763b36> in entrena(self, X, y, Xtest, ytest)
#      36         #args=(X, y), input / output data
#      37         # salida, regresa el costo y los gradientes
# ---> 38         salida = optimize.minimize(self.obtenPesosNN, pesos, jac=True, method='BFGS',                                  args=(X, y), options=opciones, callback=self.actualizaPesos)
#      39
#      40         self.NN.setPesos(salida.x)
#
# c:\users\luisj\appdata\local\programs\python\python36-32\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     595         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'bfgs':
# --> 597         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     598     elif meth == 'newton-cg':
#     599         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# c:\users\luisj\appdata\local\programs\python\python36-32\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     998         gfk = gfkp1
#     999         if callback is not None:
# -> 1000             callback(xk)
#    1001         k += 1
#    1002         gnorm = vecnorm(gfk, ord=norm)
#
# <ipython-input-63-421145763b36> in actualizaPesos(self, params)
#       8         self.NN.setPesos(params)
#       9         self.Costos.append(self.NN.funcionCosto(self.X, self.y))
# ---> 10         self.CostosTest.append(self.NN.costFunction(self.Xtest, self.ytest))
#      11
#      12     def obtenPesosNN(self, params, X, y):
#
# AttributeError: 'RedNeuronal' object has no attribute 'costFunction'
